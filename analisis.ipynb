# %%
import pandas as pd

df = pd.read_csv("../data/muestra_recetas.csv")
df
# Out:
#                         name  calories   fat  carbs  protein
# 0     1 tablespoon olive oil     376.0  21.0   24.0     23.0
# 1                   1 banana     205.0   9.0   30.0      5.0
# 2                    1 apple     210.0   8.0   39.0      3.0
# 3       1 baked sweet potato     149.0   6.0   17.0      7.0
# 4    1 grilled salmon fillet     296.0  11.0    8.0     35.0
# 5            1 boiled potato     262.0  10.0   28.0      7.0
# 6                1/2 avocado     477.0  29.0   28.0     17.0
# 7            1 medium carrot     375.0  24.0   24.0     18.0
# 8         1 tablespoon honey     294.0  15.0   36.0      6.0
# 9          1 turkey sandwich     403.0   6.0   51.0     37.0
# 10         1 hard boiled egg     644.0  29.0   72.0     31.0
# 11   1 tablespoon mayonnaise     312.0  17.0   24.0     11.0
# 12               1 slice ham     508.0  25.0   24.0     25.0
# 13         1 slice pineapple     354.0  11.0   62.0      4.0
# ...
